# %%
import pandas as pd

files=[
{"file":"map_cities"},
{"file":"map_cancellation_reasons"},
{"file":"bulk_rides"},
{"file":"map_payment_methods"},
{"file":"map_ride_statuses"},
{"file":"map_vechile_makes"},
{"file":"map_vechile_types"}
]

for file in files:
    url=f"https://uberstorageaccountruchi.blob.core.windows.net/githubdata/data/{file['file']}.json.json?sp=r&st=2026-04-16T07:18:08Z&se=2026-04-20T15:33:08Z&spr=https&sv=2025-11-05&sr=c&sig=Zv%2FuJkzeaD4BR6QbFFu%2FFIAobfUeSTR978vyo9WKJ%2B8%3D"

    df=pd.read_json(url)
    df_spark=spark.createDataFrame(df)

# Writing data to the bronze layer
    df_spark.write.mode("overwrite").format("delta").option("overwriteSchema","true").saveAsTable(f"uber_project.bronze_layer.{file['file']}")

# %%
# %sql
select * from uber_project.bronze_layer.rides_raw

# %%
# %sql
select * from uber_project.bronze_layer.bulk_rides

# %%
# %sql
select * from uber_project.bronze_layer.stg_rides

# %%
import pandas as pd

files=[
{"file":"map_cities"},
{"file":"map_cancellation_reasons"},
{"file":"bulk_rides"},
{"file":"map_payment_methods"},
{"file":"map_ride_statuses"},
{"file":"map_vechile_makes"},
{"file":"map_vechile_types"}
]

for file in files:
    url=f"https://uberstorageaccountruchi.blob.core.windows.net/githubdata/data/{file['file']}.json.json?sp=r&st=2026-04-16T07:18:08Z&se=2026-04-20T15:33:08Z&spr=https&sv=2025-11-05&sr=c&sig=Zv%2FuJkzeaD4BR6QbFFu%2FFIAobfUeSTR978vyo9WKJ%2B8%3D"

    df=pd.read_json(url)
    df_spark=spark.createDataFrame(df)

# Writing data to the bronze layer
    df_spark.write.mode("overwrite").format("delta").option("overwriteSchema","true").saveAsTable(f"uber_project.bronze_layer.{file['file']}")
